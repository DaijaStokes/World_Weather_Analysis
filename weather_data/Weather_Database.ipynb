# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

# %%
import requests
from config import weather_api_key

# %%
# Generate 1,500 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=1500)
lngs = np.random.uniform(-180.0,180.0,size=1500)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['bluff', 'tasiilaq', 'punta arenas', 'auki', 'korla', 'padang', 'sao joao da barra', 'poum', 'praia da vitoria', 'luderitz'] Generate 598

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | auki
# Processing Record 5 of Set 1 | korla
# Processing Record 6 of Set 1 | padang
# Processing Record 7 of Set 1 | sao joao da barra
# Processing Record 8 of Set 1 | poum
# Processing Record 9 of Set 1 | praia da vitoria
# Processing Record 10 of Set 1 | luderitz
# Processing Record 11 of Set 1 | batemans bay
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | san francisco
# Processing Record 14 of Set 1 | saint-denis
# Processing Record 15 of Set 1 | codrington
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | haljala
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 1 | soyo
# Processing Record 23 of Set 1 | anan
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | qasigiannguit
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | batticaloa
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | luanda
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | kahului
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 1 | broken hill
# Processing Record 40 of Set 1 | honiara
# Processing Record 41 of Set 1 | mitzic
# Processing Record 42 of Set 1 | tomigusuku
# Processing Record 43 of Set 1 | constitucion
# Processing Record 44 of Set 1 | namatanai
# Processing Record 45 of Set 1 | araria
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | darnah
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | slave lake
# Processing Record 50 of Set 1 | pontianak
# Processing Record 1 of Set 2 | olafsvik
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | mettlach
# Processing Record 5 of Set 2 | marfino
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | kurilsk
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | mwandiga
# Processing Record 14 of Set 2 | taoudenni
# Processing Record 15 of Set 2 | ahuimanu
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | la ronge
# Processing Record 18 of Set 2 | bonavista
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | la libertad
# Processing Record 22 of Set 2 | carlsbad
# Processing Record 23 of Set 2 | rosetta
# Processing Record 24 of Set 2 | arrifes
# Processing Record 25 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 2 | igarapava
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | watertown
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | te anau
# Processing Record 33 of Set 2 | charlestown
# Processing Record 34 of Set 2 | labytnangi
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | isangel
# Processing Record 38 of Set 2 | grand gaube
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | chase
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | vardo
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | ketchikan
# Processing Record 50 of Set 2 | luwuk
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 3 | ahipara
# Processing Record 4 of Set 3 | dauphin
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | hambantota
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | kisangani
# Processing Record 11 of Set 3 | faya
# Processing Record 12 of Set 3 | santiago del estero
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | beyneu
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | batagay-alyta
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | yumen
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | yelizovo
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | broome
# Processing Record 23 of Set 3 | hirara
# Processing Record 24 of Set 3 | quatre cocos
# Processing Record 25 of Set 3 | yerbogachen
# Processing Record 26 of Set 3 | salym
# Processing Record 27 of Set 3 | ushtobe
# Processing Record 28 of Set 3 | konispol
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | kenai
# Processing Record 32 of Set 3 | hammerfest
# Processing Record 33 of Set 3 | rizhao
# Processing Record 34 of Set 3 | benguela
# Processing Record 35 of Set 3 | puchezh
# Processing Record 36 of Set 3 | aswan
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | paamiut
# Processing Record 39 of Set 3 | shingu
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 3 | umba
# Processing Record 44 of Set 3 | cherskiy
# Processing Record 45 of Set 3 | zheleznodorozhnyy
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | moses lake
# Processing Record 48 of Set 3 | patos de minas
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 50 of Set 3 | port hawkesbury
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | norman wells
# Processing Record 6 of Set 4 | richmond
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | dandong
# Processing Record 9 of Set 4 | escanaba
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | beloha
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | sompeta
# Processing Record 14 of Set 4 | lagos
# Processing Record 15 of Set 4 | port-gentil
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | mwinilunga
# Processing Record 18 of Set 4 | husavik
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | niquelandia
# Processing Record 21 of Set 4 | hamilton
# Processing Record 22 of Set 4 | lodja
# Processing Record 23 of Set 4 | eureka
# Processing Record 24 of Set 4 | sechura
# Processing Record 25 of Set 4 | rocha
# Processing Record 26 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 4 | french harbor
# Processing Record 28 of Set 4 | upernavik
# Processing Record 29 of Set 4 | east millcreek
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | japura
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | mae sai
# Processing Record 34 of Set 4 | puerto narino
# Processing Record 35 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 4 | buarcos
# Processing Record 37 of Set 4 | mollendo
# Processing Record 38 of Set 4 | jamestown
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | puerto tejada
# Processing Record 41 of Set 4 | bloomfield
# Processing Record 42 of Set 4 | ferme-neuve
# Processing Record 43 of Set 4 | mabama
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | kuryk
# Processing Record 48 of Set 4 | qaanaaq
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | sosnovo-ozerskoye
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | margate
# Processing Record 4 of Set 5 | yarada
# Processing Record 5 of Set 5 | leshan
# Processing Record 6 of Set 5 | kashan
# Processing Record 7 of Set 5 | kumano
# Processing Record 8 of Set 5 | najran
# Processing Record 9 of Set 5 | aykhal
# Processing Record 10 of Set 5 | castlegar
# Processing Record 11 of Set 5 | saint-leu
# Processing Record 12 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 5 | avera
# Processing Record 14 of Set 5 | cape town
# Processing Record 15 of Set 5 | conceicao do araguaia
# Processing Record 16 of Set 5 | las vegas
# Processing Record 17 of Set 5 | kabanjahe
# Processing Record 18 of Set 5 | kununurra
# Processing Record 19 of Set 5 | hualmay
# Processing Record 20 of Set 5 | san javier
# Processing Record 21 of Set 5 | kpandae
# Processing Record 22 of Set 5 | atambua
# Processing Record 23 of Set 5 | fallon
# Processing Record 24 of Set 5 | inirida
# Processing Record 25 of Set 5 | coahuayana
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | ponta do sol
# Processing Record 29 of Set 5 | spornoye
# Processing Record 30 of Set 5 | eyl
# Processing Record 31 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 5 | mar del plata
# Processing Record 34 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 35 of Set 5 | cabo san lucas
# Processing Record 36 of Set 5 | roma
# Processing Record 37 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 5 | waingapu
# Processing Record 39 of Set 5 | grindavik
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | zapolyarnyy
# Processing Record 42 of Set 5 | bambous virieux
# Processing Record 43 of Set 5 | flin flon
# Processing Record 44 of Set 5 | nemuro
# Processing Record 45 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 46 of Set 5 | tra vinh
# Processing Record 47 of Set 5 | caiaponia
# Processing Record 48 of Set 5 | victoria
# Processing Record 49 of Set 5 | mahebourg
# Processing Record 50 of Set 5 | xadani
# City not found. Skipping...
# Processing Record 1 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 6 | dalton
# Processing Record 3 of Set 6 | chuy
# Processing Record 4 of Set 6 | cambridge
# Processing Record 5 of Set 6 | matane
# Processing Record 6 of Set 6 | ust-maya
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | talara
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | ayios matthaios
# City not found. Skipping...
# Processing Record 11 of Set 6 | ancud
# Processing Record 12 of Set 6 | batagay
# Processing Record 13 of Set 6 | lata
# Processing Record 14 of Set 6 | adeje
# Processing Record 15 of Set 6 | portland
# Processing Record 16 of Set 6 | znamenka
# Processing Record 17 of Set 6 | biryukove
# Processing Record 18 of Set 6 | krasnoselkup
# Processing Record 19 of Set 6 | chiredzi
# Processing Record 20 of Set 6 | brae
# Processing Record 21 of Set 6 | vao
# Processing Record 22 of Set 6 | valparaiso
# Processing Record 23 of Set 6 | hokitika
# Processing Record 24 of Set 6 | tura
# Processing Record 25 of Set 6 | boyolangu
# Processing Record 26 of Set 6 | nishihara
# Processing Record 27 of Set 6 | havelock
# Processing Record 28 of Set 6 | villa union
# Processing Record 29 of Set 6 | puerto del rosario
# Processing Record 30 of Set 6 | cairns
# Processing Record 31 of Set 6 | galveston
# Processing Record 32 of Set 6 | moose factory
# Processing Record 33 of Set 6 | volksrust
# Processing Record 34 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 6 | ulladulla
# Processing Record 36 of Set 6 | alofi
# Processing Record 37 of Set 6 | lima
# Processing Record 38 of Set 6 | saint anthony
# Processing Record 39 of Set 6 | meulaboh
# Processing Record 40 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 6 | fussen
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | sembe
# Processing Record 44 of Set 6 | hsinhua
# City not found. Skipping...
# Processing Record 45 of Set 6 | menongue
# Processing Record 46 of Set 6 | maceio
# Processing Record 47 of Set 6 | mae sot
# Processing Record 48 of Set 6 | castro
# Processing Record 49 of Set 6 | redlands
# Processing Record 50 of Set 6 | hofu
# Processing Record 1 of Set 7 | marsa matruh
# Processing Record 2 of Set 7 | vilcun
# Processing Record 3 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 7 | chicama
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | cabedelo
# Processing Record 7 of Set 7 | inyonga
# Processing Record 8 of Set 7 | nobeoka
# Processing Record 9 of Set 7 | maldonado
# Processing Record 10 of Set 7 | general pico
# Processing Record 11 of Set 7 | daoukro
# Processing Record 12 of Set 7 | neiafu
# Processing Record 13 of Set 7 | mogoytuy
# Processing Record 14 of Set 7 | chapais
# Processing Record 15 of Set 7 | nikolskoye
# Processing Record 16 of Set 7 | kotka
# Processing Record 17 of Set 7 | labuhan
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | kamachumu
# Processing Record 20 of Set 7 | fairbanks
# Processing Record 21 of Set 7 | jacmel
# Processing Record 22 of Set 7 | liaocheng
# Processing Record 23 of Set 7 | catuday
# Processing Record 24 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 7 | terre haute
# Processing Record 26 of Set 7 | launceston
# Processing Record 27 of Set 7 | saint-augustin
# Processing Record 28 of Set 7 | port macquarie
# Processing Record 29 of Set 7 | denpasar
# Processing Record 30 of Set 7 | dabat
# Processing Record 31 of Set 7 | manavalakurichi
# Processing Record 32 of Set 7 | dingle
# Processing Record 33 of Set 7 | monte alegre
# Processing Record 34 of Set 7 | mindelo
# Processing Record 35 of Set 7 | camacha
# Processing Record 36 of Set 7 | kohlu
# Processing Record 37 of Set 7 | alugan
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | altamont
# Processing Record 40 of Set 7 | romny
# Processing Record 41 of Set 7 | xinyang
# Processing Record 42 of Set 7 | bilma
# Processing Record 43 of Set 7 | aleksandrovskoye
# Processing Record 44 of Set 7 | nanzhang
# Processing Record 45 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 46 of Set 7 | bilibino
# Processing Record 47 of Set 7 | leh
# Processing Record 48 of Set 7 | noumea
# Processing Record 49 of Set 7 | mayumba
# Processing Record 50 of Set 7 | los llanos de aridane
# Processing Record 1 of Set 8 | talakan
# Processing Record 2 of Set 8 | saint-michel-des-saints
# Processing Record 3 of Set 8 | zyryanka
# Processing Record 4 of Set 8 | perth
# Processing Record 5 of Set 8 | ranong
# Processing Record 6 of Set 8 | nanortalik
# Processing Record 7 of Set 8 | escarcega
# Processing Record 8 of Set 8 | sao gotardo
# Processing Record 9 of Set 8 | tefe
# Processing Record 10 of Set 8 | villa carlos paz
# Processing Record 11 of Set 8 | lompoc
# Processing Record 12 of Set 8 | xuddur
# Processing Record 13 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 8 | yar-sale
# Processing Record 15 of Set 8 | calama
# Processing Record 16 of Set 8 | requena
# Processing Record 17 of Set 8 | fort nelson
# Processing Record 18 of Set 8 | canutama
# Processing Record 19 of Set 8 | lagoa
# Processing Record 20 of Set 8 | college
# Processing Record 21 of Set 8 | san cristobal
# Processing Record 22 of Set 8 | reconquista
# Processing Record 23 of Set 8 | lagdo
# Processing Record 24 of Set 8 | baykit
# Processing Record 25 of Set 8 | alyangula
# Processing Record 26 of Set 8 | revelstoke
# Processing Record 27 of Set 8 | kulhudhuffushi
# Processing Record 28 of Set 8 | iquitos
# Processing Record 29 of Set 8 | serafimovich
# Processing Record 30 of Set 8 | axim
# Processing Record 31 of Set 8 | mocuba
# Processing Record 32 of Set 8 | torbay
# Processing Record 33 of Set 8 | caravelas
# Processing Record 34 of Set 8 | tommot
# Processing Record 35 of Set 8 | farau
# Processing Record 36 of Set 8 | tezu
# Processing Record 37 of Set 8 | kavieng
# Processing Record 38 of Set 8 | ulu-telyak
# Processing Record 39 of Set 8 | teya
# Processing Record 40 of Set 8 | urengoy
# Processing Record 41 of Set 8 | anadyr
# Processing Record 42 of Set 8 | vigrestad
# Processing Record 43 of Set 8 | ife
# Processing Record 44 of Set 8 | salinopolis
# Processing Record 45 of Set 8 | aleppo
# Processing Record 46 of Set 8 | newport
# Processing Record 47 of Set 8 | sola
# Processing Record 48 of Set 8 | atar
# Processing Record 49 of Set 8 | hay river
# Processing Record 50 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 9 | aketi
# Processing Record 2 of Set 9 | kitimat
# Processing Record 3 of Set 9 | garowe
# Processing Record 4 of Set 9 | prieska
# Processing Record 5 of Set 9 | diourbel
# Processing Record 6 of Set 9 | marquette
# Processing Record 7 of Set 9 | srandakan
# Processing Record 8 of Set 9 | asau
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | vila franca do campo
# Processing Record 11 of Set 9 | champerico
# Processing Record 12 of Set 9 | imeni poliny osipenko
# Processing Record 13 of Set 9 | sao jose da coroa grande
# Processing Record 14 of Set 9 | salalah
# Processing Record 15 of Set 9 | tutoia
# Processing Record 16 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 17 of Set 9 | pitimbu
# Processing Record 18 of Set 9 | villa del rosario
# Processing Record 19 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 9 | koeru
# Processing Record 21 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 9 | surt
# Processing Record 23 of Set 9 | graaff-reinet
# Processing Record 24 of Set 9 | komsomolskiy
# Processing Record 25 of Set 9 | ambulu
# Processing Record 26 of Set 9 | novyy oskol
# Processing Record 27 of Set 9 | christchurch
# Processing Record 28 of Set 9 | kangaatsiaq
# Processing Record 29 of Set 9 | maarianhamina
# Processing Record 30 of Set 9 | carutapera
# Processing Record 31 of Set 9 | chunhuhub
# Processing Record 32 of Set 9 | candelaria
# Processing Record 33 of Set 9 | taguatinga
# Processing Record 34 of Set 9 | wassenaar
# Processing Record 35 of Set 9 | juneau
# Processing Record 36 of Set 9 | boditi
# Processing Record 37 of Set 9 | pontarlier
# Processing Record 38 of Set 9 | belmonte
# Processing Record 39 of Set 9 | araouane
# Processing Record 40 of Set 9 | stornoway
# Processing Record 41 of Set 9 | teeli
# Processing Record 42 of Set 9 | bay roberts
# Processing Record 43 of Set 9 | pringsewu
# Processing Record 44 of Set 9 | kharitonovo
# Processing Record 45 of Set 9 | alcaniz
# Processing Record 46 of Set 9 | siavonga
# Processing Record 47 of Set 9 | arlit
# Processing Record 48 of Set 9 | gari
# Processing Record 49 of Set 9 | jumla
# Processing Record 50 of Set 9 | gorontalo
# Processing Record 1 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 2 of Set 10 | springbok
# Processing Record 3 of Set 10 | marsh harbour
# Processing Record 4 of Set 10 | miles city
# Processing Record 5 of Set 10 | ust-ishim
# Processing Record 6 of Set 10 | dekoa
# City not found. Skipping...
# Processing Record 7 of Set 10 | winneba
# Processing Record 8 of Set 10 | aberdeen
# Processing Record 9 of Set 10 | morros
# Processing Record 10 of Set 10 | smithers
# Processing Record 11 of Set 10 | ayagoz
# Processing Record 12 of Set 10 | kudahuvadhoo
# Processing Record 13 of Set 10 | deputatskiy
# Processing Record 14 of Set 10 | arman
# Processing Record 15 of Set 10 | bure
# Processing Record 16 of Set 10 | hobyo
# Processing Record 17 of Set 10 | sagarejo
# Processing Record 18 of Set 10 | kashi
# Processing Record 19 of Set 10 | sorland
# Processing Record 20 of Set 10 | mulki
# Processing Record 21 of Set 10 | carepa
# Processing Record 22 of Set 10 | sobolevo
# Processing Record 23 of Set 10 | mariental
# Processing Record 24 of Set 10 | wajir
# Processing Record 25 of Set 10 | badiraguato
# Processing Record 26 of Set 10 | kizema
# Processing Record 27 of Set 10 | kimbe
# Processing Record 28 of Set 10 | bull savanna
# Processing Record 29 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 10 | lahaina
# Processing Record 31 of Set 10 | magole
# Processing Record 32 of Set 10 | isoka
# Processing Record 33 of Set 10 | cordele
# Processing Record 34 of Set 10 | ladario
# Processing Record 35 of Set 10 | kirakira
# Processing Record 36 of Set 10 | lavrentiya
# Processing Record 37 of Set 10 | cap malheureux
# Processing Record 38 of Set 10 | pisco
# Processing Record 39 of Set 10 | caraballeda
# Processing Record 40 of Set 10 | aldama
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | vredendal
# Processing Record 43 of Set 10 | nagorsk
# Processing Record 44 of Set 10 | tazovskiy
# Processing Record 45 of Set 10 | port hedland
# Processing Record 46 of Set 10 | bexhill
# Processing Record 47 of Set 10 | nadym
# Processing Record 48 of Set 10 | santa maria
# Processing Record 49 of Set 10 | rabo de peixe
# Processing Record 50 of Set 10 | itaueira
# Processing Record 1 of Set 11 | iracoubo
# Processing Record 2 of Set 11 | erzin
# Processing Record 3 of Set 11 | ostrovnoy
# Processing Record 4 of Set 11 | ambilobe
# Processing Record 5 of Set 11 | kralendijk
# Processing Record 6 of Set 11 | kouroussa
# Processing Record 7 of Set 11 | arys
# Processing Record 8 of Set 11 | vanimo
# Processing Record 9 of Set 11 | vila velha
# Processing Record 10 of Set 11 | correntina
# Processing Record 11 of Set 11 | paita
# Processing Record 12 of Set 11 | litovko
# Processing Record 13 of Set 11 | makakilo city
# Processing Record 14 of Set 11 | atherton
# Processing Record 15 of Set 11 | yanam
# Processing Record 16 of Set 11 | port blair
# Processing Record 17 of Set 11 | tautira
# Processing Record 18 of Set 11 | ipixuna
# Processing Record 19 of Set 11 | ust-ilimsk
# Processing Record 20 of Set 11 | catamarca
# Processing Record 21 of Set 11 | hami
# Processing Record 22 of Set 11 | saint-pierre
# Processing Record 23 of Set 11 | verkhoyansk
# Processing Record 24 of Set 11 | bandar penggaram
# City not found. Skipping...
# Processing Record 25 of Set 11 | new ulm
# Processing Record 26 of Set 11 | acapulco
# Processing Record 27 of Set 11 | half moon bay
# Processing Record 28 of Set 11 | lazaro cardenas
# Processing Record 29 of Set 11 | male
# Processing Record 30 of Set 11 | camopi
# Processing Record 31 of Set 11 | channel-port aux basques
# Processing Record 32 of Set 11 | saint-georges
# Processing Record 33 of Set 11 | port shepstone
# Processing Record 34 of Set 11 | talnakh
# Processing Record 35 of Set 11 | rovaniemi
# Processing Record 36 of Set 11 | boende
# Processing Record 37 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 38 of Set 11 | edd
# Processing Record 39 of Set 11 | katsuura
# Processing Record 40 of Set 11 | buchanan
# Processing Record 41 of Set 11 | tiarei
# Processing Record 42 of Set 11 | tucumcari
# Processing Record 43 of Set 11 | rognan
# Processing Record 44 of Set 11 | andenes
# Processing Record 45 of Set 11 | oriximina
# Processing Record 46 of Set 11 | bereda
# Processing Record 47 of Set 11 | oranjemund
# Processing Record 48 of Set 11 | matagami
# Processing Record 49 of Set 11 | voznesenye
# Processing Record 50 of Set 11 | lufilufi
# Processing Record 1 of Set 12 | itoman
# Processing Record 2 of Set 12 | ohara
# Processing Record 3 of Set 12 | sokolo
# Processing Record 4 of Set 12 | middletown
# Processing Record 5 of Set 12 | bitung
# Processing Record 6 of Set 12 | ternate
# Processing Record 7 of Set 12 | bell ville
# Processing Record 8 of Set 12 | souillac
# Processing Record 9 of Set 12 | ngaoundere
# Processing Record 10 of Set 12 | henties bay
# Processing Record 11 of Set 12 | larsnes
# Processing Record 12 of Set 12 | noshiro
# Processing Record 13 of Set 12 | coquimbo
# Processing Record 14 of Set 12 | haradok
# Processing Record 15 of Set 12 | porto novo
# Processing Record 16 of Set 12 | yarensk
# Processing Record 17 of Set 12 | bowen
# Processing Record 18 of Set 12 | nohfelden
# Processing Record 19 of Set 12 | thinadhoo
# Processing Record 20 of Set 12 | samana
# Processing Record 21 of Set 12 | laguna
# Processing Record 22 of Set 12 | ambanja
# Processing Record 23 of Set 12 | shakawe
# Processing Record 24 of Set 12 | nisia floresta
# Processing Record 25 of Set 12 | westport
# Processing Record 26 of Set 12 | samarai
# Processing Record 27 of Set 12 | fortuna
# Processing Record 28 of Set 12 | jinchang
# Processing Record 29 of Set 12 | hollins
# Processing Record 30 of Set 12 | urumqi
# Processing Record 31 of Set 12 | morehead
# Processing Record 32 of Set 12 | dunedin
# Processing Record 33 of Set 12 | misratah
# Processing Record 34 of Set 12 | road town
# Processing Record 35 of Set 12 | parana
# Processing Record 36 of Set 12 | oktyabrskiy
# Processing Record 37 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 12 | adrar
# Processing Record 39 of Set 12 | savannakhet
# Processing Record 40 of Set 12 | bingol
# Processing Record 41 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 12 | ko samui
# Processing Record 43 of Set 12 | nautla
# Processing Record 44 of Set 12 | jiayuguan
# Processing Record 45 of Set 12 | grenville
# Processing Record 46 of Set 12 | pozo colorado
# Processing Record 47 of Set 12 | saurimo
# Processing Record 48 of Set 12 | itarema
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 551

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0            bluff      NZ  2022-06-08 03:29:37 -46.6000  168.3333     50.81
# 1         tasiilaq      GL  2022-06-08 03:29:38  65.6145  -37.6368     39.36
# 2     punta arenas      CL  2022-06-08 03:25:27 -53.1500  -70.9167     42.91
# 3             auki      SB  2022-06-08 03:29:40  -8.7676  160.7034     84.96
# 4            korla      CN  2022-06-08 03:29:40  41.7597   86.1469     81.21
# ..             ...     ...                  ...      ...       ...       ...
# 546      jiayuguan      CN  2022-06-08 03:34:48  39.8167   98.3000     72.93
# 547      grenville      GD  2022-06-08 03:34:49  12.1167  -61.6167     79.92
# 548  pozo colorado      PY  2022-06-08 03:34:49 -23.4923  -58.7972     58.32
# 549        saurimo      AO  2022-06-08 03:34:49  -9.6608   20.3916     53.65
# 550        itarema      BR  2022-06-08 03:34:49  -2.9248  -39.9167     74.26
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          71          64        4.79       broken clouds
# 1          61          82        3.20       broken clouds
# 2          65          75       11.50       broken clouds
# 3          66          88        2.55       moderate rain
# 4          19           0        9.28           clear sky
# ..        ...         ...         ...                 ...
# 546        15          47        0.78    scattered clouds
# 547        84          31       17.47    scattered clouds
# 548        96           1        4.50           clear sky
# 549        57           2        5.75           clear sky
# 550        91          77        6.87       broken clouds
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                         0.0                         0
# 1                         0.0                         0
# 2                         0.0                         0
# 3                         0.0                         0
# 4                         0.0                         0
# ..                        ...                       ...
# 546                       0.0                         0
# 547                       0.0                         0
# 548                       0.0                         0
# 549                       0.0                         0
# 550                       0.0                         0
#
# [551 rows x 12 columns]

# %%
output_data_file = "weather_data/WeatherPy_Database.csv"
challenge_city_data_df.to_csv(output_data_file, index_label="City_ID")
